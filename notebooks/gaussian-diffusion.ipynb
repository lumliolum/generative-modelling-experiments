# %% [markdown]
# In this notebook, I will try to train a diffusion model on a gaussian mixture model with 2 clusters. At the end, if I can sample, it will be really helpful.
#
# The next target is to simulate the setting where the data is missing that is we have projected data similar to g-sure based diffusion.
