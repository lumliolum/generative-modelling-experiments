# %%
import numpy as np

# %%
A = (1 - 0.01) * np.eye(3)

# %%
X = 0.01 * np.array([
    [0.2, 0, 0],
    [0, 0.1, 0],
    [0, 0, 0]
])

# %%
A - X
# Out:
# array([[0.988, 0.   , 0.   ],
#        [0.   , 0.989, 0.   ],
#        [0.   , 0.   , 0.99 ]])
